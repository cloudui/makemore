# %%
words = open('names.txt', 'r').read().splitlines()

# %%
words[:10]
# Out:
# ['emma',
#  'olivia',
#  'ava',
#  'isabella',
#  'sophia',
#  'charlotte',
#  'mia',
#  'amelia',
#  'harper',
#  'evelyn']

# %%
b = {}

for w in words:
    chs = ['.', '.'] + list(w) + ['.']
    for ch1, ch2, ch3 in zip(chs, chs[1:], chs[2:]):
        bigram = (ch1, ch2, ch3)
        b[bigram] = b.get(bigram, 0) + 1

# %%
sorted(b.items(), key=lambda kv: kv[1], reverse=True)
# Out:
# [(('.', '.', 'a'), 4410),
#  (('.', '.', 'k'), 2963),
#  (('.', '.', 'm'), 2538),
#  (('.', '.', 'j'), 2422),
#  (('.', '.', 's'), 2055),
#  (('a', 'h', '.'), 1714),
#  (('.', '.', 'd'), 1690),
#  (('n', 'a', '.'), 1673),
#  (('.', '.', 'r'), 1639),
#  (('.', '.', 'l'), 1572),
#  (('.', '.', 'c'), 1542),
#  (('.', '.', 'e'), 1531),
#  (('a', 'n', '.'), 1509),
#  (('o', 'n', '.'), 1503),
#  (('.', 'm', 'a'), 1453),
#  (('.', '.', 't'), 1308),
#  (('.', '.', 'b'), 1306),
#  (('.', 'j', 'a'), 1255),
#  (('.', 'k', 'a'), 1254),
#  (('e', 'n', '.'), 1217),
#  (('.', '.', 'n'), 1146),
#  (('l', 'y', 'n'), 976),
#  (('y', 'n', '.'), 953),
#  (('a', 'r', 'i'), 950),
#  (('.', '.', 'z'), 929),
#  (('i', 'a', '.'), 903),
#  (('.', '.', 'h'), 874),
#  (('i', 'e', '.'), 858),
#  (('a', 'n', 'n'), 825),
#  (('e', 'l', 'l'), 822),
#  (('a', 'n', 'a'), 804),
#  (('i', 'a', 'n'), 790),
#  (('m', 'a', 'r'), 776),
#  (('i', 'n', '.'), 766),
#  (('e', 'l', '.'), 727),
#  (('y', 'a', '.'), 716),
#  (('a', 'n', 'i'), 703),
#  (('.', 'd', 'a'), 700),
#  (('l', 'a', '.'), 684),
#  (('e', 'r', '.'), 683),
#  (('.', '.', 'g'), 669),
#  (('i', 'y', 'a'), 669),
#  (('l', 'a', 'n'), 647),
#  (('.', 'b', 'r'), 646),
#  (('n', 'n', 'a'), 633),
#  (('.', 'a', 'l'), 632),
#  (('.', 'c', 'a'), 628),
#  (('r', 'a', '.'), 627),
#  (('n', 'i', '.'), 625),
#  (('.', 'a', 'n'), 623),
#  (('n', 'n', '.'), 619),
#  (('n', 'e', '.'), 607),
#  (('e', 'e', '.'), 605),
#  (('e', 'y', '.'), 602),
#  (('.', 'k', 'e'), 601),
#  (('a', 'l', 'e'), 601),
#  (('.', 's', 'a'), 595),
#  (('.', '.', 'i'), 591),
#  (('a', 'l', 'i'), 575),
#  (('s', 'h', 'a'), 562),
#  (('e', 'l', 'i'), 537),
#  (('.', '.', 'y'), 535),
#  (('.', 'd', 'e'), 524),
#  (('l', 'i', 'a'), 518),
#  (('l', 'e', 'e'), 517),
#  (('y', 'n', 'n'), 516),
#  (('.', '.', 'p'), 515),
#  (('y', 'a', 'h'), 511),
#  (('.', 'h', 'a'), 505),
#  (('l', 'i', 'n'), 505),
#  (('r', 'i', 'a'), 499),
#  (('.', 'e', 'l'), 488),
#  (('a', 'y', 'l'), 483),
#  (('.', 'a', 'r'), 482),
#  (('y', 'a', 'n'), 479),
#  (('.', 'r', 'a'), 472),
#  (('.', 'n', 'a'), 470),
#  (('h', 'a', 'n'), 469),
#  (('.', 'l', 'a'), 463),
#  (('i', 'a', 'h'), 461),
#  (('.', 'z', 'a'), 456),
#  (('r', 'i', '.'), 452),
#  (('l', 'e', 'y'), 443),
#  (('.', 's', 'h'), 434),
#  (('a', 'm', 'a'), 431),
#  (('.', 'j', 'o'), 429),
#  (('.', 't', 'a'), 424),
#  (('.', '.', 'f'), 417),
#  (('.', 'j', 'e'), 403),
#  (('l', 'e', 'i'), 401),
#  (('i', 'e', 'l'), 395),
#  (('.', '.', 'o'), 394),
#  (('r', 'i', 'e'), 394),
#  (('.', 'm', 'i'), 393),
#  (('a', 'n', 'd'), 392),
#  (('a', 'y', 'a'), 389),
#  (('.', 'a', 'm'), 384),
#  (('l', 'e', 'n'), 383),
#  (('.', 'r', 'o'), 382),
#  (('y', 'l', 'a'), 381),
#  (('i', 'n', 'a'), 379),
#  (('t', 'o', 'n'), 377),
#  (('.', '.', 'v'), 376),
#  (('a', 'r', 'a'), 371),
#  (('.', 'a', 'd'), 366),
#  (('.', 'l', 'e'), 366),
#  (('l', 'e', '.'), 362),
#  (('r', 'i', 's'), 360),
#  (('a', 'm', 'i'), 355),
#  (('e', 'l', 'y'), 353),
#  (('a', 'l', 'a'), 353),
#  (('.', 'c', 'h'), 352),
#  (('s', 'o', 'n'), 341),
#  (('l', 'l', 'a'), 337),
#  (('l', 'l', 'e'), 331),
#  (('h', 'a', 'r'), 329),
#  (('d', 'e', 'n'), 318),
#  (('a', 'l', 'y'), 310),
#  (('e', 'l', 'a'), 308),
#  (('.', '.', 'w'), 307),
#  (('a', 'v', 'i'), 306),
#  (('y', 'l', 'e'), 303),
#  (('i', 'g', 'h'), 290),
#  (('i', 'o', 'n'), 290),
#  (('.', 'e', 'm'), 288),
#  (('a', 'r', 'l'), 287),
#  (('i', 's', '.'), 287),
#  (('a', 'e', 'l'), 287),
#  (('l', 'i', 'e'), 285),
#  (('h', 'a', '.'), 284),
#  (('.', 'm', 'e'), 284),
#  (('r', 'e', 'n'), 281),
#  (('u', 's', '.'), 280),
#  (('i', 'l', 'a'), 279),
#  (('e', 'n', 'a'), 279),
#  (('e', 'i', 'g'), 279),
#  (('a', 's', 'h'), 276),
#  (('m', 'a', 'n'), 274),
#  (('l', 'l', 'i'), 271),
#  (('l', 'y', '.'), 270),
#  (('.', 'l', 'i'), 269),
#  (('.', 'r', 'e'), 268),
#  (('e', 'r', 'i'), 268),
#  (('n', 'n', 'e'), 261),
#  (('a', 'i', 'l'), 259),
#  (('m', 'i', 'l'), 259),
#  (('.', 'c', 'o'), 255),
#  (('b', 'r', 'i'), 254),
#  (('r', 'a', 'y'), 254),
#  (('.', 'b', 'e'), 253),
#  (('s', 'a', '.'), 253),
#  (('k', 'e', 'n'), 252),
#  (('.', 'k', 'i'), 250),
#  (('i', 'r', 'a'), 248),
#  (('r', 'a', 'n'), 248),
#  (('i', 'r', '.'), 248),
#  (('.', 'y', 'a'), 246),
#  (('.', 'a', 'v'), 243),
#  (('i', 'n', 'e'), 241),
#  (('e', 'n', 'n'), 240),
#  (('.', 'k', 'h'), 240),
#  (('v', 'a', 'n'), 237),
#  (('c', 'h', 'a'), 236),
#  (('g', 'h', '.'), 235),
#  (('c', 'e', '.'), 234),
#  (('l', 'a', 'y'), 234),
#  (('r', 'i', 'n'), 234),
#  (('r', 'e', '.'), 231),
#  (('.', 'k', 'y'), 229),
#  (('a', 'r', '.'), 228),
#  (('s', 'e', '.'), 228),
#  (('i', 's', 'h'), 227),
#  (('a', 'm', 'e'), 226),
#  (('.', 'n', 'i'), 226),
#  (('k', 'a', 'i'), 226),
#  (('l', 'a', 'h'), 224),
#  (('a', 'n', 'e'), 224),
#  (('n', 'i', 'e'), 223),
#  (('r', 'a', 'h'), 222),
#  (('l', 'i', '.'), 221),
#  (('n', 'n', 'i'), 221),
#  (('o', 'r', 'i'), 220),
#  (('e', 'l', 'e'), 219),
#  (('k', 'a', 'r'), 218),
#  (('d', 'e', 'l'), 217),
#  (('k', 'a', 'y'), 215),
#  (('j', 'a', 'y'), 212),
#  (('i', 'l', 'l'), 211),
#  (('m', 'a', 'l'), 210),
#  (('k', 'a', '.'), 210),
#  (('m', 'e', 'r'), 209),
#  (('y', 'l', 'i'), 209),
#  (('.', 't', 'r'), 209),
#  (('r', 'i', 'c'), 209),
#  (('l', 'i', 's'), 208),
#  (('.', 'a', 'a'), 207),
#  (('d', 'a', 'n'), 207),
#  (('r', 'e', 'e'), 205),
#  (('i', 'l', 'y'), 203),
#  (('e', 't', 't'), 203),
#  (('d', 'a', 'l'), 203),
#  (('l', 'l', '.'), 203),
#  (('b', 'r', 'a'), 203),
#  (('o', 'r', 'a'), 202),
#  (('b', 'e', 'l'), 201),
#  (('r', 'y', '.'), 201),
#  (('.', 'r', 'i'), 201),
#  (('m', 'o', 'n'), 201),
#  (('e', 'e', 'n'), 200),
#  (('a', 'r', 'e'), 198),
#  (('i', 'l', 'e'), 197),
#  (('t', 'a', '.'), 197),
#  (('d', 'a', '.'), 197),
#  (('e', 'a', 'n'), 196),
#  (('a', 'l', 'l'), 196),
#  (('r', 'o', 's'), 196),
#  (('a', 'r', 'y'), 195),
#  (('a', 'd', 'e'), 194),
#  (('.', 'a', 's'), 194),
#  (('o', 'n', 'n'), 194),
#  (('c', 'a', 'r'), 193),
#  (('n', 'y', '.'), 192),
#  (('.', 'k', 'o'), 192),
#  (('a', 'r', 'r'), 192),
#  (('.', 'a', 'b'), 190),
#  (('a', 'd', 'i'), 190),
#  (('b', 'r', 'e'), 189),
#  (('a', 'i', 'r'), 189),
#  (('a', 'm', '.'), 189),
#  (('o', 'n', 'i'), 189),
#  (('m', 'e', 'l'), 188),
#  (('.', 'l', 'o'), 186),
#  (('n', 'a', 'h'), 185),
#  (('n', 'd', 'r'), 184),
#  (('a', 'i', '.'), 183),
#  (('.', 's', 'e'), 182),
#  (('r', 'r', 'i'), 182),
#  (('.', 't', 'e'), 181),
#  (('i', 'l', 'i'), 180),
#  (('e', 'y', 'a'), 179),
#  (('t', 'h', '.'), 178),
#  (('.', 'j', 'u'), 178),
#  (('a', 'y', 'd'), 178),
#  (('l', 'a', 'i'), 177),
#  (('a', 'n', 't'), 177),
#  (('a', 'i', 'n'), 177),
#  (('t', 'e', '.'), 175),
#  (('.', 'p', 'a'), 175),
#  (('i', 'k', 'a'), 175),
#  (('a', 'n', 'y'), 175),
#  (('a', 'l', '.'), 175),
#  (('m', 'a', '.'), 174),
#  (('a', 'a', 'n'), 174),
#  (('a', 'b', 'e'), 173),
#  (('l', 'e', 'a'), 173),
#  (('.', 'a', 'y'), 173),
#  (('a', 's', '.'), 173),
#  (('.', 's', 'i'), 172),
#  (('m', 'i', 'r'), 172),
#  (('s', 'i', 'a'), 171),
#  (('k', 'h', 'a'), 171),
#  (('e', 'r', 'e'), 170),
#  (('s', 'h', 'i'), 170),
#  (('.', 'b', 'a'), 169),
#  (('t', 'h', 'a'), 168),
#  (('e', 'n', 'i'), 168),
#  (('.', 'm', 'o'), 168),
#  (('k', 'a', 'l'), 168),
#  (('r', 'o', 'n'), 168),
#  (('a', 'v', 'e'), 166),
#  (('o', 's', 'e'), 166),
#  (('s', 's', 'a'), 166),
#  (('.', 'g', 'r'), 165),
#  (('s', 't', 'o'), 165),
#  (('.', 'n', 'e'), 164),
#  (('a', 'd', 'a'), 164),
#  (('r', 'e', 'y'), 163),
#  (('a', 'y', '.'), 163),
#  (('.', 'l', 'u'), 162),
#  (('d', 'r', 'i'), 162),
#  (('a', 'v', 'a'), 161),
#  (('.', 'v', 'i'), 161),
#  (('e', 'm', 'i'), 160),
#  (('v', 'e', 'r'), 160),
#  (('s', 't', 'i'), 159),
#  (('s', 'a', 'n'), 159),
#  (('.', 'f', 'a'), 158),
#  (('e', 'a', '.'), 158),
#  (('a', 's', 'i'), 157),
#  (('.', 'n', 'o'), 156),
#  (('i', 's', 't'), 156),
#  (('.', 'e', 'v'), 154),
#  (('s', 't', 'e'), 154),
#  (('.', 'a', 'i'), 154),
#  (('t', 'a', 'l'), 153),
#  (('l', 'a', 'r'), 153),
#  (('m', 'a', 'y'), 153),
#  (('e', 's', 's'), 153),
#  (('h', 'a', 'l'), 153),
#  (('d', 'a', 'r'), 153),
#  (('h', 'a', 'm'), 153),
#  (('.', 's', 'o'), 152),
#  (('.', 'a', 'u'), 152),
#  (('b', 'e', 'r'), 152),
#  (('.', 'a', 'z'), 152),
#  (('e', 'n', 'e'), 151),
#  (('k', 'a', 'm'), 151),
#  (('.', 'h', 'e'), 151),
#  (('j', 'a', 'm'), 151),
#  (('s', 'h', '.'), 149),
#  (('d', 'e', 'r'), 149),
#  (('o', 'r', '.'), 148),
#  (('v', 'i', 'n'), 148),
#  (('v', 'i', 'a'), 147),
#  (('e', 's', 't'), 147),
#  (('l', 'o', 'n'), 147),
#  (('o', 'n', 'a'), 147),
#  (('a', 'e', '.'), 147),
#  (('r', 'l', 'e'), 146),
#  (('r', 'i', 'o'), 146),
#  (('n', 'e', 'l'), 145),
#  (('a', 'i', 's'), 145),
#  (('e', 'r', 'a'), 145),
#  (('n', 'l', 'e'), 143),
#  (('r', 'e', 'l'), 143),
#  (('h', 'i', '.'), 143),
#  (('i', 's', 'a'), 142),
#  (('e', 'v', 'e'), 142),
#  (('t', 'i', 'n'), 142),
#  (('a', 't', 'h'), 142),
#  (('d', 'o', 'n'), 142),
#  (('s', 'e', 'n'), 142),
#  (('m', 'i', 'n'), 141),
#  (('.', 's', 'u'), 141),
#  (('k', 'e', 'l'), 141),
#  (('t', 'a', 'n'), 141),
#  (('n', 'i', 'a'), 141),
#  (('r', 'y', 'n'), 140),
#  (('j', 'a', 'n'), 140),
#  (('n', 'a', 'l'), 140),
#  (('e', 'r', 'r'), 140),
#  (('e', 'm', 'a'), 140),
#  (('s', 't', 'a'), 139),
#  (('i', 'o', '.'), 139),
#  (('s', 'l', 'e'), 138),
#  (('a', 'i', 'd'), 138),
#  (('e', 's', '.'), 138),
#  (('l', 'o', 'r'), 137),
#  (('m', 'a', 'd'), 136),
#  (('s', 'a', 'm'), 136),
#  (('.', 'g', 'a'), 136),
#  (('r', 'i', 'y'), 136),
#  (('.', 's', 't'), 135),
#  (('i', 'e', 'r'), 135),
#  (('.', 'z', 'e'), 135),
#  (('j', 'a', 'h'), 135),
#  (('k', 'i', 'n'), 134),
#  (('.', '.', 'x'), 134),
#  (('l', 'i', 'l'), 133),
#  (('e', 'v', 'a'), 133),
#  (('h', 'a', 'y'), 133),
#  (('t', 'e', 'r'), 133),
#  (('a', 'y', 's'), 133),
#  (('.', 't', 'y'), 133),
#  (('h', 'e', 'r'), 132),
#  (('r', 'a', 'i'), 132),
#  (('e', 'o', 'n'), 131),
#  (('.', 'd', 'i'), 130),
#  (('c', 'h', 'e'), 130),
#  (('a', 'c', 'e'), 129),
#  (('i', 'c', 'k'), 129),
#  (('d', 'y', '.'), 128),
#  (('.', 'g', 'i'), 128),
#  (('e', 'm', '.'), 128),
#  (('y', 'o', 'n'), 128),
#  (('r', 'a', 'e'), 127),
#  (('n', 'c', 'e'), 127),
#  (('i', 's', 'e'), 126),
#  (('n', 'd', '.'), 126),
#  (('.', 'p', 'r'), 125),
#  (('i', 'n', 'g'), 125),
#  (('.', 'i', 's'), 124),
#  (('m', 'i', '.'), 124),
#  (('i', 't', 'h'), 124),
#  (('l', 'l', 'y'), 124),
#  (('o', 'l', 'a'), 124),
#  (('u', 'r', 'i'), 123),
#  (('a', 'z', 'a'), 123),
#  (('j', 'e', 'r'), 123),
#  (('i', 'r', 'e'), 122),
#  (('i', 's', 's'), 122),
#  (('t', 't', 'e'), 121),
#  (('.', 'v', 'a'), 121),
#  (('c', 'a', 'l'), 121),
#  (('a', 'k', 'a'), 121),
#  (('z', 'a', 'r'), 121),
#  (('y', 'd', 'e'), 121),
#  (('v', 'i', '.'), 121),
#  (('g', 'r', 'a'), 120),
#  (('m', 'a', 'i'), 120),
#  (('c', 'k', '.'), 120),
#  (('i', 'l', '.'), 119),
#  (('h', 'a', 'i'), 119),
#  (('e', 'n', 'd'), 119),
#  (('v', 'e', 'n'), 119),
#  (('.', 'd', 'o'), 119),
#  (('r', 'i', 't'), 119),
#  (('v', 'o', 'n'), 119),
#  (('.', 'l', 'y'), 118),
#  (('r', 'y', 'a'), 118),
#  (('l', 'i', 'y'), 117),
#  (('s', 'e', 'l'), 117),
#  (('i', 'm', 'a'), 117),
#  (('b', 'r', 'y'), 116),
#  (('e', 't', 'h'), 114),
#  (('d', 'r', 'e'), 113),
#  (('n', 'a', 'y'), 113),
#  (('k', 'a', 's'), 113),
#  (('t', 'e', 'n'), 113),
#  (('h', 'e', 'l'), 112),
#  (('o', 'r', 'e'), 112),
#  (('.', 't', 'o'), 112),
#  (('a', 't', 'a'), 111),
#  (('.', 'r', 'y'), 111),
#  (('e', 'i', 'l'), 111),
#  (('r', 'a', 'l'), 111),
#  (('h', 'r', 'i'), 111),
#  (('a', 'h', 'a'), 111),
#  (('t', 'o', 'r'), 110),
#  (('.', 'g', 'e'), 110),
#  (('a', 'n', 'g'), 110),
#  (('i', 'd', 'e'), 110),
#  (('m', 'a', 'k'), 109),
#  (('.', 't', 'i'), 109),
#  (('n', 'd', 'e'), 109),
#  (('a', 'u', 'r'), 108),
#  (('.', 'r', 'u'), 108),
#  (('d', 'y', 'n'), 108),
#  (('n', 'i', 'y'), 108),
#  (('s', 'h', 'e'), 108),
#  (('t', 'r', 'i'), 107),
#  (('n', 'i', 's'), 107),
#  (('n', 'o', '.'), 107),
#  (('e', 't', '.'), 106),
#  (('d', 'i', 'e'), 106),
#  (('t', 'h', 'e'), 106),
#  (('h', 'e', 'n'), 106),
#  (('a', 'd', '.'), 106),
#  (('a', 'i', 'a'), 105),
#  (('j', 'a', 'i'), 105),
#  (('.', 'o', 'l'), 104),
#  (('k', 'y', 'l'), 104),
#  (('d', 'i', '.'), 104),
#  (('n', 'a', 'n'), 104),
#  (('t', 'r', 'e'), 104),
#  (('l', 'o', '.'), 104),
#  (('r', 'a', 'c'), 103),
#  (('a', 'r', 'o'), 103),
#  (('i', 'n', 'n'), 103),
#  (('.', 'm', 'y'), 103),
#  (('s', 's', 'i'), 103),
#  (('t', 't', '.'), 102),
#  (('c', 'o', 'r'), 102),
#  (('a', 's', 't'), 102),
#  (('a', 'r', 't'), 102),
#  (('n', 'a', 'i'), 102),
#  (('n', 'o', 'r'), 101),
#  (('n', 'a', 't'), 101),
#  (('e', 'r', 'l'), 101),
#  (('l', 'e', 's'), 101),
#  (('a', 'm', 'o'), 101),
#  (('a', 'h', 'i'), 101),
#  (('a', 'i', 'y'), 101),
#  (('o', 'n', 't'), 101),
#  (('e', 'm', 'm'), 100),
#  (('t', 'y', 'n'), 100),
#  (('h', 'a', 'd'), 99),
#  (('g', 'a', 'n'), 99),
#  (('.', 't', 'h'), 99),
#  (('i', 't', 'a'), 99),
#  (('l', 'y', 'a'), 99),
#  (('a', 'n', 's'), 99),
#  (('a', 'k', 'i'), 99),
#  (('a', 'n', 'o'), 98),
#  (('d', 'i', 'a'), 98),
#  (('z', 'a', '.'), 98),
#  (('m', 'o', 'r'), 98),
#  (('a', 'y', 'n'), 98),
#  (('a', 'k', 'e'), 98),
#  (('m', 'a', 't'), 98),
#  (('y', 'i', 'a'), 98),
#  (('r', 'l', 'i'), 97),
#  (('y', 'e', 'l'), 97),
#  (('z', 'a', 'y'), 97),
#  (('r', 'a', 'm'), 97),
#  (('v', 'a', 'l'), 96),
#  (('u', 'l', 'i'), 96),
#  (('y', 'r', 'i'), 96),
#  (('a', 's', 's'), 96),
#  (('i', 'd', 'a'), 96),
#  (('h', 'o', 'n'), 96),
#  (('.', 'k', 'r'), 96),
#  (('m', 'i', 'a'), 95),
#  (('e', 'n', 't'), 95),
#  (('v', 'i', 'e'), 95),
#  (('i', 'm', '.'), 95),
#  (('a', 'd', 'd'), 94),
#  (('c', 'h', 'i'), 94),
#  (('i', 'k', '.'), 94),
#  (('v', 'a', '.'), 93),
#  (('i', 'z', 'a'), 93),
#  (('n', 'e', 's'), 93),
#  (('j', 'o', 's'), 93),
#  (('k', 'a', 't'), 93),
#  (('.', 'e', 's'), 93),
#  (('y', 'n', 'e'), 93),
#  (('a', 'z', 'i'), 93),
#  (('c', 'a', 'm'), 92),
#  (('.', 'p', 'e'), 92),
#  (('e', 'a', 'h'), 92),
#  (('.', '.', 'q'), 92),
#  (('d', 'e', '.'), 92),
#  (('c', 'e', 'l'), 92),
#  (('.', 'n', 'y'), 92),
#  (('a', 'r', 's'), 92),
#  (('a', 'r', 'd'), 92),
#  (('l', 'e', 't'), 91),
#  (('.', 'w', 'i'), 91),
#  (('i', 'e', 'n'), 91),
#  (('a', 'm', 'y'), 91),
#  (('e', 'i', '.'), 91),
#  (('.', 'z', 'y'), 91),
#  (('d', 'a', 'm'), 91),
#  (('r', 'o', '.'), 91),
#  (('.', 'a', 'h'), 91),
#  (('i', 'u', 's'), 91),
#  (('o', 'v', 'a'), 90),
#  (('s', 'a', 'l'), 90),
#  (('n', 'i', 'c'), 90),
#  (('y', 'n', 'a'), 90),
#  (('n', 'd', 'a'), 90),
#  (('.', 'e', 'r'), 90),
#  (('d', 'a', 'y'), 90),
#  (('.', 'r', 'h'), 90),
#  (('v', 'i', 'o'), 89),
#  (('s', 'y', 'n'), 89),
#  (('n', 'a', 's'), 89),
#  (('m', 'a', 'h'), 89),
#  (('t', 'y', '.'), 88),
#  (('a', 'r', 'm'), 88),
#  (('a', 'h', 'm'), 88),
#  (('r', 'e', 't'), 87),
#  (('l', 'e', 'r'), 87),
#  (('i', 'n', 'i'), 87),
#  (('j', 'e', 'n'), 87),
#  (('i', 'n', 'd'), 87),
#  (('g', 'e', 'n'), 86),
#  (('d', 'r', 'a'), 86),
#  (('r', 'e', 's'), 86),
#  (('n', 'g', 'e'), 86),
#  (('o', 'n', 'e'), 86),
#  (('.', 'z', 'i'), 86),
#  (('.', 'y', 'u'), 86),
#  (('.', 'y', 'o'), 86),
#  (('a', 'b', 'r'), 85),
#  (('g', 'e', 'l'), 85),
#  (('.', 'b', 'l'), 85),
#  (('d', 'e', 'm'), 85),
#  (('e', 'y', 'l'), 85),
#  (('.', 'm', 'u'), 85),
#  (('e', 'r', 'y'), 84),
#  (('l', 'y', 's'), 84),
#  (('h', 'i', 'r'), 84),
#  (('b', 'e', 'n'), 84),
#  (('o', 'l', 'u'), 84),
#  (('u', 'w', 'a'), 84),
#  (('e', 'l', 'o'), 83),
#  (('z', 'e', 'l'), 83),
#  (('o', 'l', 'e'), 83),
#  (('s', 'a', 'r'), 83),
#  (('l', 'e', 'x'), 83),
#  (('e', 'v', 'i'), 83),
#  (('a', 'n', 'c'), 83),
#  (('a', 'a', 'r'), 83),
#  (('e', 's', 'h'), 83),
#  (('.', 'q', 'u'), 82),
#  (('j', 'a', 's'), 82),
#  (('m', 'i', 'k'), 82),
#  (('r', 'e', 'i'), 82),
#  (('a', 's', 'e'), 82),
#  (('y', 'l', 'y'), 82),
#  (('n', 'g', '.'), 82),
#  (('n', 't', 'a'), 82),
#  (('h', 'i', 'a'), 81),
#  (('l', 'i', 'z'), 81),
#  (('t', 'a', 'y'), 81),
#  (('m', 'a', 'e'), 81),
#  (('j', 'a', 'c'), 81),
#  (('a', 'l', 'o'), 81),
#  (('h', 'i', 'l'), 81),
#  (('n', 'i', 'k'), 81),
#  (('n', 'n', 'y'), 81),
#  (('s', 's', 'e'), 81),
#  (('r', 'l', 'y'), 80),
#  (('e', 'm', 'e'), 80),
#  (('.', 'e', 'd'), 80),
#  (('n', 'e', 'e'), 80),
#  (('r', 'r', 'a'), 80),
#  (('m', 'i', 'e'), 80),
#  (('n', 'y', 'a'), 80),
#  (('o', 'u', 'r'), 79),
#  (('.', 'f', 'r'), 79),
#  (('a', 'y', 'v'), 79),
#  (('e', 'e', 'l'), 79),
#  (('l', 'u', 'w'), 79),
#  (('i', 'v', 'i'), 78),
#  (('z', 'i', 'e'), 78),
#  (('c', 'o', 'l'), 78),
#  (('y', 'r', 'a'), 78),
#  (('l', 'i', 'o'), 78),
#  (('.', '.', 'u'), 78),
#  (('u', 'n', '.'), 78),
#  (('p', 'e', 'r'), 77),
#  (('m', 'a', 'c'), 77),
#  (('o', 'r', 'd'), 77),
#  (('a', 'c', 'h'), 77),
#  (('.', 'h', 'o'), 77),
#  (('n', 't', 'e'), 77),
#  (('y', 'a', 'r'), 77),
#  (('j', 'a', 'l'), 77),
#  (('.', 'd', 'r'), 77),
#  (('.', 'b', 'o'), 77),
#  (('y', 'c', 'e'), 77),
#  (('o', 's', '.'), 77),
#  (('s', 'a', 'b'), 76),
#  (('v', 'e', 'l'), 76),
#  (('a', 'b', 'i'), 76),
#  (('e', 'r', 's'), 76),
#  (('n', 'e', 'y'), 76),
#  (('i', 'c', 'h'), 76),
#  (('c', 'a', 's'), 76),
#  (('a', 'y', 'e'), 76),
#  (('u', 's', 't'), 76),
#  (('n', 'a', 'v'), 76),
#  (('d', 'i', 'n'), 76),
#  (('t', 'r', 'a'), 76),
#  (('e', 'e', 'm'), 76),
#  (('u', 'a', 'n'), 76),
#  (('r', 'y', 'l'), 75),
#  (('i', 'r', 'i'), 75),
#  (('m', 'i', 'y'), 75),
#  (('u', 'e', 'l'), 75),
#  (('k', 'e', 'i'), 75),
#  (('k', 'y', 'n'), 75),
#  (('t', 'i', 'a'), 75),
#  (('.', 'a', 'k'), 75),
#  (('o', 'm', 'i'), 74),
#  (('j', 'u', 'l'), 74),
#  (('s', 'i', 'e'), 74),
#  (('a', 't', 'i'), 74),
#  (('a', 'h', 'l'), 73),
#  (('.', 'j', 'i'), 73),
#  (('a', 't', 't'), 73),
#  (('z', 'a', 'n'), 73),
#  (('e', 'e', 'r'), 73),
#  (('m', 'm', 'a'), 72),
#  (('.', 'z', 'o'), 72),
#  (('r', 'e', 'a'), 72),
#  (('.', 'a', 't'), 72),
#  (('y', 'l', 'o'), 72),
#  (('t', 'h', 'i'), 72),
#  (('k', 'e', 'y'), 72),
#  (('n', 'a', 'r'), 72),
#  (('r', 'r', 'e'), 72),
#  (('.', 'f', 'i'), 71),
#  (('.', 's', 'y'), 71),
#  (('c', 'i', 'a'), 71),
#  (('d', 'e', 's'), 71),
#  (('o', 'h', 'a'), 71),
#  (('s', 'a', 'i'), 71),
#  (('t', 'a', 'r'), 71),
#  (('z', 'i', 'a'), 71),
#  (('i', 'n', 'o'), 71),
#  (('e', 'd', '.'), 71),
#  (('o', 'l', 'l'), 70),
#  (('q', 'u', 'e'), 70),
#  (('i', 'v', 'a'), 70),
#  (('a', 'r', 'c'), 70),
#  (('k', 'a', 'n'), 70),
#  (('o', 'l', 'i'), 69),
#  (('b', 'r', 'o'), 69),
#  (('l', 'u', 'c'), 69),
#  (('k', 'e', 'r'), 69),
#  (('d', 'a', 'i'), 69),
#  (('r', 'e', 'm'), 69),
#  (('a', 'd', 'r'), 69),
#  (('c', 'h', 'r'), 69),
#  (('d', 'a', 'v'), 69),
#  (('z', 'a', 'i'), 69),
#  (('l', 'a', 'm'), 69),
#  (('y', 'a', 's'), 69),
#  (('m', 'e', 'e'), 69),
#  (('i', 's', 'o'), 68),
#  (('.', 'c', 'l'), 68),
#  (('e', 'n', 'z'), 68),
#  (('r', 'y', 's'), 68),
#  (('.', 'w', 'a'), 68),
#  (('s', 'i', 'r'), 68),
#  (('i', 'h', 'a'), 68),
#  (('o', 'u', 's'), 68),
#  (('s', 'e', 'r'), 67),
#  (('q', 'u', 'i'), 67),
#  (('.', 'v', 'e'), 67),
#  (('m', 'i', 'c'), 67),
#  (('.', 'c', 'r'), 67),
#  (('.', 'h', 'u'), 67),
#  (('.', 'i', 'l'), 67),
#  (('s', 't', 'y'), 67),
#  (('a', 'i', 'z'), 67),
#  (('l', 'a', 'k'), 66),
#  (('a', 't', 'e'), 66),
#  (('i', 'c', '.'), 66),
#  (('z', 'a', 'l'), 66),
#  (('i', 'd', '.'), 66),
#  (('o', 'm', 'a'), 66),
#  (('h', 'a', 'w'), 66),
#  (('a', 'u', 'n'), 66),
#  (('.', 'c', 'e'), 65),
#  (('i', 'l', 'o'), 65),
#  (('a', 'b', 'd'), 65),
#  (('d', 'o', '.'), 65),
#  (('d', 'i', 'l'), 64),
#  (('e', 'r', 'o'), 64),
#  (('k', 'r', 'i'), 64),
#  (('y', 's', '.'), 64),
#  (('o', 'r', 'r'), 64),
#  (('t', 'e', 'l'), 63),
#  (('i', 's', 'l'), 63),
#  (('n', 's', 'l'), 63),
#  (('i', 'c', 'e'), 63),
#  (('m', 'y', 'a'), 63),
#  (('o', 's', 'a'), 63),
#  (('c', 'a', '.'), 63),
#  (('n', 'e', 't'), 63),
#  (('k', 'e', 'e'), 63),
#  (('k', 'o', 'l'), 63),
#  (('d', 'e', 'e'), 63),
#  (('r', 'i', 'l'), 62),
#  (('o', 'r', 'y'), 62),
#  (('k', 'o', 'r'), 62),
#  (('j', 'a', 'k'), 62),
#  (('h', 'a', 's'), 62),
#  (('h', 'a', 'a'), 62),
#  (('i', 'm', 'i'), 62),
#  (('p', 'h', 'i'), 61),
#  (('b', 'e', 't'), 61),
#  (('u', 'n', 'a'), 61),
#  (('a', 'r', 'k'), 61),
#  (('e', 's', 'l'), 61),
#  (('a', 'y', 't'), 61),
#  (('i', 'v', 'e'), 61),
#  (('j', 'e', 's'), 61),
#  (('e', 'n', 's'), 61),
#  (('e', 'n', 'l'), 61),
#  (('k', 'a', 'e'), 61),
#  (('.', 'w', 'e'), 61),
#  (('.', 'y', 'e'), 61),
#  (('a', 'z', 'e'), 60),
#  (('c', 'l', 'a'), 60),
#  (('m', 'e', 'n'), 60),
#  (('l', 'e', 'o'), 60),
#  (('.', 'e', 'n'), 60),
#  (('n', 'd', 'i'), 60),
#  (('r', 'i', 'k'), 60),
#  (('.', 'i', 'n'), 60),
#  (('t', 'l', 'e'), 60),
#  (('s', 'i', 'n'), 60),
#  (('t', 'i', '.'), 60),
#  (('g', 'e', 'r'), 60),
#  (('a', 's', 'a'), 60),
#  (('a', 'c', 'k'), 59),
#  (('m', 'b', 'e'), 59),
#  (('c', 'i', 'e'), 59),
#  (('.', 'i', 'z'), 59),
#  (('a', 'd', 'o'), 59),
#  (('d', 'o', 'r'), 59),
#  (('y', 's', 'e'), 59),
#  (('s', 'l', 'y'), 59),
#  (('z', 'l', 'e'), 59),
#  (('i', 'j', 'a'), 59),
#  (('n', 'e', 'r'), 59),
#  (('w', 'a', '.'), 59),
#  (('a', 'v', 'o'), 59),
#  (('i', 'i', '.'), 59),
#  (('k', 'o', '.'), 59),
#  (('l', 'l', 'o'), 58),
#  (('i', 'n', 's'), 58),
#  (('n', 'i', 't'), 58),
#  (('e', 'n', 'c'), 58),
#  (('y', 's', 'o'), 58),
#  (('g', 'h', 'a'), 58),
#  (('a', 'y', 'c'), 58),
#  (('i', 'z', 'e'), 58),
#  (('v', 'i', 'k'), 58),
#  (('k', 'i', '.'), 58),
#  (('t', 'o', '.'), 58),
#  (('e', 's', 'i'), 57),
#  (('h', 'i', 'n'), 57),
#  (('e', 'i', 'a'), 57),
#  (('i', 'c', 'a'), 57),
#  (('r', 'o', 'm'), 57),
#  (('r', 'm', 'a'), 57),
#  (('h', 'y', 'a'), 57),
#  (('a', 'd', 'y'), 57),
#  (('a', 'h', 'n'), 57),
#  (('.', 'x', 'a'), 57),
#  (('r', 'd', '.'), 57),
#  (('w', 'i', 'l'), 56),
#  (('e', 'd', 'e'), 56),
#  (('a', 'c', 'i'), 56),
#  (('u', 'r', 'a'), 56),
#  (('h', 'l', 'a'), 56),
#  (('j', 'a', 'z'), 56),
#  (('s', 's', '.'), 56),
#  (('a', 't', '.'), 56),
#  (('c', 'a', 'i'), 56),
#  (('d', 'e', 'v'), 56),
#  (('v', 'a', 'r'), 56),
#  (('q', 'u', 'a'), 56),
#  (('.', 's', 'k'), 55),
#  (('b', 'y', '.'), 55),
#  (('k', 'i', 'a'), 55),
#  (('w', 'i', 'n'), 55),
#  (('t', 'a', 'v'), 55),
#  (('j', 'o', 'h'), 55),
#  (('l', 'a', 's'), 55),
#  (('e', 'd', 'a'), 55),
#  (('f', 'a', 'r'), 55),
#  (('z', 'e', 'n'), 55),
#  (('j', 'a', '.'), 55),
#  (('.', 'a', 'e'), 55),
#  (('.', 'h', 'i'), 55),
#  (('i', 't', '.'), 55),
#  (('a', 'y', 'm'), 55),
#  (('t', 'a', 'i'), 55),
#  (('i', 'a', 's'), 55),
#  (('l', 'i', 'v'), 54),
#  (('f', 'i', 'n'), 54),
#  (('j', 'o', 'r'), 54),
#  (('m', 'y', '.'), 54),
#  (('r', 'n', 'e'), 54),
#  (('b', 'l', 'a'), 54),
#  (('i', 'a', 'r'), 54),
#  (('a', 'l', 'd'), 54),
#  (('a', 'm', 'r'), 54),
#  (('f', 'r', 'a'), 54),
#  (('n', 't', 'o'), 54),
#  (('s', 'i', '.'), 54),
#  (('.', 'e', 'i'), 54),
#  (('n', 's', 'h'), 54),
#  (('y', 'r', 'e'), 54),
#  (('n', 'd', 'y'), 53),
#  (('h', 'a', 'v'), 53),
#  (('k', 'a', 'h'), 53),
#  (('t', 't', 'a'), 53),
#  (('s', 'o', 'l'), 53),
#  (('r', 'i', 'g'), 53),
#  (('a', 'e', 'd'), 53),
#  (('n', 'o', 'v'), 52),
#  (('c', 'k', 'e'), 52),
#  (('e', 'g', 'a'), 52),
#  (('i', 'a', 'm'), 52),
#  (('.', 'p', 'h'), 52),
#  (('e', 's', 'a'), 52),
#  (('.', 'e', 'z'), 52),
#  (('u', 'e', '.'), 52),
#  (('h', 'y', 'l'), 52),
#  (('a', 'k', 'y'), 52),
#  (('a', 'w', 'n'), 52),
#  (('a', 'j', 'a'), 52),
#  (('i', 'k', 'o'), 52),
#  (('d', 'd', 'i'), 51),
#  (('g', 'a', 'r'), 51),
#  (('n', 'd', 'o'), 51),
#  (('e', 'i', 'r'), 51),
#  (('s', 'e', 'y'), 51),
#  (('t', 'i', 'e'), 51),
#  (('a', 'm', 'b'), 51),
#  (('p', 'r', 'i'), 51),
#  (('e', 'r', 't'), 51),
#  (('r', 'i', 'd'), 51),
#  (('k', 'i', 'e'), 51),
#  (('j', 'a', 'e'), 51),
#  (('i', 't', 't'), 51),
#  (('h', 'i', 't'), 51),
#  (('a', 'i', 'm'), 51),
#  (('w', 'n', '.'), 51),
#  (('r', 'a', 'd'), 51),
#  (('a', 'y', 'o'), 51),
#  (('e', 'a', 'l'), 51),
#  (('g', 'i', 'a'), 50),
#  (('e', 'p', 'h'), 50),
#  (('a', 'i', 't'), 50),
#  (('i', 'x', '.'), 50),
#  (('z', 'a', 'h'), 50),
#  (('c', 'a', 'y'), 50),
#  (('a', 'n', 'u'), 50),
#  (('e', 'k', '.'), 50),
#  (('r', 'i', 'u'), 50),
#  (('a', 'u', 'd'), 49),
#  (('.', 'i', 'v'), 49),
#  (('.', 'i', 'r'), 49),
#  (('e', 's', 'e'), 49),
#  (('m', 'y', 'l'), 49),
#  (('.', 'f', 'e'), 49),
#  (('i', 'd', 'y'), 49),
#  (('y', 'a', 'l'), 49),
#  (('r', 'e', 'd'), 49),
#  (('h', 'a', 'e'), 49),
#  (('g', 'r', 'e'), 49),
#  (('k', 'y', 'r'), 49),
#  (('b', 'a', 'r'), 49),
#  (('a', 'n', 'v'), 49),
#  (('e', 'r', 'm'), 49),
#  (('m', 'e', 's'), 49),
#  (('j', 'a', 'r'), 49),
#  (('a', 'r', 'v'), 49),
#  (('n', 't', 'i'), 48),
#  (('u', 'r', 'e'), 48),
#  (('k', 'e', '.'), 48),
#  (('.', 'm', 'c'), 48),
#  (('a', 'k', 'o'), 48),
#  (('w', 'y', 'n'), 48),
#  (('u', 'l', 'a'), 48),
#  (('m', 'e', 'i'), 48),
#  (('n', 'a', 'e'), 48),
#  (('o', 'm', 'e'), 48),
#  (('m', 'a', 's'), 48),
#  (('r', 'a', 's'), 48),
#  (('j', 'a', 'v'), 48),
#  (('u', 'i', 'n'), 47),
#  (('o', 'e', 'l'), 47),
#  (('.', 'z', 'u'), 47),
#  (('w', 'e', 'n'), 47),
#  (('n', 'o', 'n'), 47),
#  (('e', 'd', 'i'), 47),
#  (('i', 'n', 'c'), 47),
#  (('a', 'a', 'd'), 47),
#  (('e', 'i', 's'), 47),
#  (('c', 'e', 'n'), 47),
#  (('.', 'o', 'r'), 47),
#  (('z', 'a', 'm'), 47),
#  (('z', 'a', 'k'), 47),
#  (('i', 'r', 'o'), 47),
#  (('a', 'a', 'l'), 46),
#  (('n', 'z', 'i'), 46),
#  (('e', 'e', 's'), 46),
#  (('l', 'a', 'u'), 46),
#  (('o', 'n', 'd'), 46),
#  (('n', 'y', 'l'), 46),
#  (('s', 'e', 'a'), 46),
#  (('e', 'm', 'o'), 46),
#  (('.', 'c', 'y'), 46),
#  (('s', 'i', 'm'), 46),
#  (('m', 'i', 's'), 46),
#  (('a', 'v', 'y'), 46),
#  (('b', 'a', '.'), 46),
#  (('u', 'm', 'a'), 46),
#  (('k', 'h', 'y'), 46),
#  (('r', 'u', 's'), 46),
#  (('a', 'h', 'e'), 46),
#  (('r', 's', 'h'), 46),
#  (('y', 'a', 'a'), 46),
#  (('p', 'a', 'r'), 45),
#  (('h', 'e', 'a'), 45),
#  (('f', 'e', 'r'), 45),
#  (('y', 's', 'i'), 45),
#  (('y', 'd', 'a'), 45),
#  (('m', 'a', 'x'), 45),
#  (('.', 'g', 'u'), 45),
#  (('n', 'v', 'i'), 45),
#  (('z', 'e', '.'), 45),
#  (('t', 'a', 'm'), 45),
#  (('a', 't', 'o'), 45),
#  (('j', 'o', 'n'), 45),
#  (('a', 'j', '.'), 45),
#  (('a', 'v', '.'), 45),
#  (('r', 'l', 'o'), 44),
#  (('s', 'k', 'y'), 44),
#  (('n', 't', 'h'), 44),
#  (('i', 't', 'y'), 44),
#  (('j', 'a', 'd'), 44),
#  (('i', 'n', 'l'), 44),
#  (('k', 'i', 'm'), 44),
#  (('o', 's', 'i'), 44),
#  (('g', 'e', '.'), 44),
#  (('f', 'r', 'e'), 44),
#  (('k', 'l', 'e'), 44),
#  (('i', 't', 'z'), 44),
#  (('s', 'a', 'h'), 44),
#  ...]

# %%
import torch

# %%
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print (x)
else:
    print ("MPS device not found.")
# Out:
# tensor([1.], device='mps:0')

# %%
chars = list('abcdefghijklmnopqrstuvwxyz')
stoi = {s:i+1 for i,s in enumerate(chars)}
stoi['.'] = 0
itos = {i:s for s,i in stoi.items()}

# %%
N = torch.zeros((27, 27, 27), dtype=torch.int32)

# %%
for w in words:
    chs = ['.', '.'] + list(w) + ['.']
    for ch1, ch2, ch3 in zip(chs, chs[1:], chs[2:]):
        ix1 = stoi[ch1]
        ix2 = stoi[ch2]
        ix3 = stoi[ch3]
        N[ix1,ix2,ix3] += 1

# %%
# validate counts are same as above
print("..a", N[0,0,1].item())
print("ah.", N[1,8,0].item())
print("na.", N[14,1,0].item())
# Out:
# ..a 4410
# ah. 1714
# na. 1673

# %%
g = torch.Generator().manual_seed(2147483647)

# %%
P = (N+1).float()
P /= P.sum(2, keepdim=True)
P[0,0].sum()
# Out:
# tensor(1.)

# %%
for i in range(10):
    ix1 = 0
    ix2 = 0
    out = []
    
    while True:
        p = P[ix1, ix2]
    
        ix1 = ix2
        ix2 = torch.multinomial(p, num_samples=1, replacement=True, generator=g).item()
        out.append(itos[ix2])
        
        if ix2 == 0:
            break
    print("".join(out))
# Out:
# makimarityharlonimittain.
# luwak.
# ka.
# da.
# samiyah.
# javer.
# gotai.
# moriellavojkwuthda.
# kaley.
# maside.

# %%
log_likelihood = 0.0
n = 0

for w in words:
    chs = ['.', '.'] + list(w) + ['.']
    for ch1, ch2, ch3 in zip(chs, chs[1:], chs[2:]):
        ix1 = stoi[ch1]
        ix2 = stoi[ch2]
        ix3 = stoi[ch3]
        prob = P[ix1, ix2, ix3]
        logprob = torch.log(prob)
        log_likelihood += logprob
        n += 1
        # print(f'{ch1}{ch2}: {prob:.4f} {logprob:.4f}')

print(f'{log_likelihood=}')
nll = -log_likelihood/n
print(f'{nll=}')
# Out:
# log_likelihood=tensor(-504653.)
# nll=tensor(2.2120)

# %% [markdown]
# # Trigram NN Optimization

# %%
import torch.nn.functional as F

# %%
# create training set
xs, ys = [], []

for w in words:
    chs = ['.', '.'] + list(w) + ['.']
    for ch1, ch2, ch3 in zip(chs, chs[1:], chs[2:]):
        ix1 = stoi[ch1]
        ix2 = stoi[ch2]
        ix3 = stoi[ch3]
        
        xs.append([ix1, ix2])
        ys.append(ix3)

xs = torch.tensor(xs)
ys = torch.tensor(ys)
num = xs.nelement() // 2
print('number of examples:', num)

# initialize network
g = torch.Generator().manual_seed(2147483647)
W = torch.randn((54,27), generator=g, requires_grad=True)
# Out:
# number of examples: 228146

# %%
for k in range(100):

    # forward pass
    xtemp = F.one_hot(xs, num_classes=27).float()
    xlen, ylen, zlen = xtemp.shape
    xenc = xtemp.reshape((xlen, ylen*zlen))
    
    logits = xenc @ W
    counts = logits.exp()
    probs = counts / counts.sum(1, keepdim=True)
    loss = -probs[torch.arange(num), ys].log().mean()
    print('loss:', loss.item())

    # backward pass
    W.grad = None
    loss.backward()

    # update
    W.data += -50 * W.grad
# Out:
# loss: 3.203230381011963
# loss: 2.8220293521881104
# loss: 2.5432095527648926
# loss: 2.44171142578125
# loss: 2.411390781402588
# loss: 2.3871679306030273
# loss: 2.3668408393859863
# loss: 2.351937770843506
# loss: 2.3434951305389404
# loss: 2.3400886058807373
# loss: 2.3388891220092773
# loss: 2.338777780532837
# loss: 2.3400020599365234
# loss: 2.3433945178985596
# loss: 2.3566362857818604
# loss: 2.367482900619507
# loss: 2.4272377490997314
# loss: 2.358185052871704
# loss: 2.3793535232543945
# loss: 2.370321750640869
# loss: 2.4235622882843018
# loss: 2.358818292617798
# loss: 2.379650592803955
# loss: 2.369866132736206
# loss: 2.4215571880340576
# loss: 2.35932993888855
# loss: 2.38138484954834
# loss: 2.3696324825286865
# loss: 2.420348644256592
# loss: 2.3596229553222656
# loss: 2.3824758529663086
# loss: 2.3694777488708496
# loss: 2.419612169265747
# loss: 2.3598012924194336
# loss: 2.3831684589385986
# loss: 2.3693742752075195
# loss: 2.4191513061523438
# loss: 2.3599119186401367
# loss: 2.383615732192993
# loss: 2.36930513381958
# loss: 2.4188613891601562
# loss: 2.3599791526794434
# loss: 2.3839035034179688
# loss: 2.3692591190338135
# loss: 2.4186811447143555
# loss: 2.360018253326416
# loss: 2.3840866088867188
# loss: 2.3692283630371094
# loss: 2.418574094772339
# loss: 2.3600380420684814
# loss: 2.38419771194458
# loss: 2.369209051132202
# loss: 2.4185166358947754
# loss: 2.3600449562072754
# loss: 2.384258270263672
# loss: 2.369196653366089
# loss: 2.418491840362549
# loss: 2.3600428104400635
# loss: 2.3842852115631104
# loss: 2.369189739227295
# loss: 2.418489456176758
# loss: 2.3600354194641113
# loss: 2.384289264678955
# loss: 2.3691864013671875
# loss: 2.4185004234313965
# loss: 2.3600237369537354
# loss: 2.384277820587158
# loss: 2.3691842555999756
# loss: 2.4185211658477783
# loss: 2.3600099086761475
# loss: 2.384255886077881
# loss: 2.369184732437134
# loss: 2.4185471534729004
# loss: 2.359995126724243
# loss: 2.384228467941284
# loss: 2.369185209274292
# loss: 2.418574571609497
# loss: 2.3599796295166016
# loss: 2.384197950363159
# loss: 2.369185447692871
# loss: 2.418602466583252
# loss: 2.359964609146118
# loss: 2.384167194366455
# loss: 2.3691866397857666
# loss: 2.418630599975586
# loss: 2.359949827194214
# loss: 2.3841352462768555
# loss: 2.369187593460083
# loss: 2.418657064437866
# loss: 2.3599355220794678
# loss: 2.3841049671173096
# loss: 2.3691883087158203
# loss: 2.418682336807251
# loss: 2.359921932220459
# loss: 2.3840746879577637
# loss: 2.3691890239715576
# loss: 2.418705940246582
# loss: 2.3599088191986084
# loss: 2.3840463161468506
# loss: 2.3691892623901367
